# %%
from mini_model import *
import itertools
# Out:
# ACT-R connection has been started.

# %%
p1 = (5, 10)
m1 = MiniModel(param_set={'difficulty':p1[0], 'payoff':p1[1]})
p2 = (5, 20)
m2 = MiniModel(param_set={'difficulty':p2[0], 'payoff':p2[1]})

# %%
m1.setup_parameters()
m1.production_at
m1.production_reward
m2.setup_parameters()
m2.production_at
m2.production_reward
# Out:
# [0.1339,
#  0.3597,
#  0.9485,
#  2.3841,
#  5.3788,
#  10.0,
#  14.6212,
#  17.6159,
#  19.0515,
#  19.6403]

# %%
sns.lineplot(x=range(len(m
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=range(len(m.production_at)), y=m.production_reward)
# Out:
# <AxesSubplot:>

# %%
difficulty = [5]
payoff = [10,20]
params = list(itertools.product(*[difficulty, payoff]))

# %%
LOAD = 0
if LOAD:
    df = pd.read_csv("./mini_model_df_20220421.txt")
else: 
    dfs = []
    for p in params:
        rs = simulation(epoch=100, time=1, param_set={'difficulty':p[0], 'payoff':p[1]})
        df = merge_simulation_data(rs)
        dfs.append(df)
    df = pd.concat(dfs)
    df.to_csv("./mini_model_df_20220421.txt", index=False)
# Out:
# ==== SIMULATED ==== epoch >> 0
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 10
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 20
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 30
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 40
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 50
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 60
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 70
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 80
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 90
# PARAMETERS:  {'difficulty': 5, 'payoff': 10}
# ==== SIMULATED ==== epoch >> 0
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 10
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 20
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 30
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 40
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 50
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 60
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 70
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 80
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}
# ==== SIMULATED ==== epoch >> 90
# PARAMETERS:  {'difficulty': 5, 'payoff': 20}

# %%
df=df.iloc[natsort.index_humansorted(df.production)]
df.head()
# Out:
#    epoch  trial production  response_time  firing_time  rewarded_time  \
# 2      3      3         P1           0.16        0.743          0.743
# 0      8      1         P1           0.16        0.111          0.111
# 3     10      3         P1           0.16        0.638          0.638
# 2     17      3         P1           0.16        0.597          0.597
# 0     22      1         P1           0.16        0.111          0.111
#
#    delivered_reward  passed_time  received_reward        u   utility      at  \
# 2            0.0669        0.061           0.0059  0.00236 -0.496303  0.0611
# 0            0.0669        0.061           0.0059  0.00236 -1.032398  0.0611
# 3            0.0669        0.061           0.0059  0.00236 -0.107312  0.0611
# 2            0.0669        0.061           0.0059  0.00236 -0.446880  0.0611
# 0            0.0669        0.061           0.0059  0.00236  1.598138  0.0611
#
#    difficulty  payoff
# 2           5      10
# 0           5      10
# 3           5      10
# 2           5      10
# 0           5      10

# %%
# order = ["P1", "P2","P3", "P4","P5","P6", "P7", "P8", "P9", "P10"]
# df_agg = df.groupby(["production", "difficulty", "payoff"])["trial"].agg(["count", "sum"]).reset_index()
# df_agg["perc"] = df_agg["count"]/df_agg["sum"]
# sns.pointplot(data=df_agg, x="production", y="perc", order=order)

# %%
def plot_actr_evc(df, subtitle=""):
    """in single plots"""
    order=["P1", "P2", "P3", "P4", "P5", "P6", "P7", "P8", "P9", "P10"]
    fig, ax = plt.subplots()
    ax2 = ax.twinx()
    ax3 = ax.twinx()
    ax4 = ax.twinx()
    #sns.displot(x=df['production'], order=order, palette="Purples", ax=ax).set_title('EVC in ACT-R: {}'.format(subtitle))
    sns.histplot(x='production', hue="production", color="production", palette="Purples", ax=ax, data=df.iloc[natsort.index_humansorted(df.production)])#.set_title('EVC in ACT-R: {}'.format(subtitle))
    sns.pointplot(x="production", y="delivered_reward", data=df, order=order, palette="Reds", ax=ax2, label="reward")
    sns.pointplot(x="production", y="at", order=order, data=df, palette="Blues", ax=ax3, label="cost")
    sns.lineplot(x="production", y="u", color="purple", data=df.iloc[natsort.index_humansorted(df.production)], ax=ax4, label="utility")
    
    #ax2.set_yticks([])
    ax3.set_yticks([])
    ax4.set_yticks([])
    
    ax.set_ylabel("")
    ax2.set_ylabel("")
    ax3.set_ylabel("")
    ax4.set_ylabel("")
    '''
    lines_1, labels_1 = ax.get_legend_handles_labels()
    lines_2, labels_2 = ax2.get_legend_handles_labels()
    lines_3, labels_3 = ax3.get_legend_handles_labels()
    lines_4, labels_4 = ax4.get_legend_handles_labels()

    lines = lines_1 + lines_2 + lines_3 + lines_4
    labels = labels_1 + labels_2 + labels_3 + labels_4

    ax.legend(lines, labels, loc=0)
    #print(lines, labels)
    '''
    #fig.legend(loc=1)

    plt.show()

# %%
plot_actr_evc(df)

# %%
df["production2"] = df["production"].apply(lambda x: x[1:]).astype(int)

# %%
sns.lineplot(data=df, x="production", y="at")
sns.lineplot(data=df, x="production", y="u")
sns.displot(data=df, x="production2", hue="payoff", kind="kde")
